# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
eda = pd.read_csv("ReadytoETA.csv")
# Out:
# /var/folders/n7/x0fwwp8x0jvgxqnmqjfvghqh0000gn/T/ipykernel_34800/1456211550.py:1: DtypeWarning: Columns (0,1,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   eda = pd.read_csv("ReadytoETA.csv")

# %%
eda
# Out:
#           budget id_original original_language  \
# 0       30000000         862                en
# 1       30000000         862                en
# 2       30000000         862                en
# 3       65000000        8844                en
# 4       65000000        8844                en
# ...          ...         ...               ...
# 178519         0       67758                en
# 178520         0       67758                en
# 178521         0       67758                en
# 178522         0      227506                en
# 178523         0      461257                en
#
#                                                  overview popularity  \
# 0       Led by Woody, Andy's toys live happily in his ...  21.946943
# 1       Led by Woody, Andy's toys live happily in his ...  21.946943
# 2       Led by Woody, Andy's toys live happily in his ...  21.946943
# 3       When siblings Judy and Peter discover an encha...  17.015539
# ...
