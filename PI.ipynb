# %%
# importacion de librerias

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import ast

# %% [markdown]
# # Proyecto Individual
# Primero vamos a hacer un analisis expliratorio del data set, donde hay datos anidados asi como columnas no necesarias para hacer el modelo de sugerencias.
#
# ## EDA
# Primero vamos a eliminar las columnas inecesarias, para ello primero vamos a ver una porcion de los datos en un `DataFrame`, luego ver cuantos indices tiene, cuantas columnas y como se estructura el `dataframe`.

# %% [markdown]
# ## Leer los archivos y darle una primera mirada

# %%
movies = pd.read_csv("./RawData/Movies/movies_dataset.csv")
movies.head()
# Out:
# /var/folders/n7/x0fwwp8x0jvgxqnmqjfvghqh0000gn/T/ipykernel_78234/1181931400.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies = pd.read_csv("./RawData/Movies/movies_dataset.csv")
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# ...

# %% [markdown]
# ## Una descripcion general de el DataFrame

# %%
movies.describe()
# Out:
#             revenue       runtime  vote_average    vote_count
# count  4.546000e+04  45203.000000  45460.000000  45460.000000
# mean   1.120935e+07     94.128199      5.618207    109.897338
# std    6.433225e+07     38.407810      1.924216    491.310374
# min    0.000000e+00      0.000000      0.000000      0.000000
# 25%    0.000000e+00     85.000000      5.000000      3.000000
# 50%    0.000000e+00     95.000000      6.000000     10.000000
# 75%    0.000000e+00    107.000000      6.800000     34.000000
# max    2.787965e+09   1256.000000     10.000000  14075.000000

# %% [markdown]
# ## Descripcion de las Columnas
#
# Queremos hacer una descripcion de las columnas para como vimos al ver los primeros 6 registros hay datos anidados asi como columnas que queremos eliminar como: 'belongs_to_collection' , 'spoken_languages', 'imdb_id', 'release_date','adult', 'original_title','poster_path' y 'homepage'.

# %%
movies.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
movies = movies.drop(['belongs_to_collection' , 'spoken_languages', 'imdb_id', 'release_date','adult', 'original_title','poster_path', 'homepage'],axis =1 );
movies
# Out:
#          budget                                             genres      id  \
# 0      30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...     862
# 1      65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...    8844
# 2             0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...   15602
# 3      16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...   31357
# 4             0                     [{'id': 35, 'name': 'Comedy'}]   11862
# ...         ...                                                ...     ...
# 45461         0  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...  439050
# 45462         0                      [{'id': 18, 'name': 'Drama'}]  111109
# 45463         0  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...   67758
# 45464         0                                                 []  227506
# 45465         0                                                 []  461257
#
# ...

# %% [markdown]
# ### Despues de remover las colimnas
#
# Quedan 17 columnas incloyendo los indices, ahora vamos a *desanidar* las columnas, primero debemos obtener mas informacion de dichas columnas.
#
# ## Desanidando los datos
#
# Ahora que hemos removido las columnas vamos a revisar como estan los datos anidados, el tipo de variable que son, `objeto`, `diccionario` u otro.

# %%
movies['genres']
# Out:
# 0        [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1        [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2        [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3        [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                           [{'id': 35, 'name': 'Comedy'}]
#                                ...
# 45461    [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                        [{'id': 18, 'name': 'Drama'}]
# 45463    [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                   []
# 45465                                                   []
# Name: genres, Length: 45466, dtype: object

# %% [markdown]
# ## Analisando el anidado
#
# Al observar que dentro de genres hay mas datos y que parecen ser un `diccionario` pero tambien parecen ser un `objeto`, vamos a observar que tipo de dato es

# %% [markdown]
# Parece que la columna genres es de tipo str en lugar de una lista de `diccionarios`. Para poder trabajar con esta columna y desanidar los datos correctamente. Para ello vamos a usar la libreria `import ast`

# %%
# Convierte la columna 'genres' de cadenas a listas de diccionarios
movies['genres'] = movies['genres'].apply(ast.literal_eval)

print(movies['genres'].apply(type).value_counts())
# Out:
# genres
# <class 'list'>    45466
# Name: count, dtype: int64

# %% [markdown]
# Intentamos desanidar los datos asumiendo que son `diccionarios`.

# %%
# Explota la columna 'genres' para separar los diccionarios en filas individuales
exploded_df = movies.explode('genres')
print(exploded_df.head())
# Out:
#      budget                           genres    id original_language  \
# 0  30000000  {'id': 16, 'name': 'Animation'}   862                en
# 0  30000000     {'id': 35, 'name': 'Comedy'}   862                en
# 0  30000000  {'id': 10751, 'name': 'Family'}   862                en
# 1  65000000  {'id': 12, 'name': 'Adventure'}  8844                en
# 1  65000000    {'id': 14, 'name': 'Fantasy'}  8844                en
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 1  When siblings Judy and Peter discover an encha...  17.015539
# 1  When siblings Judy and Peter discover an encha...  17.015539
#
#                                 production_companies  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# ...

# %% [markdown]
# Al intentar desanidar nos funciona, asi que intentamos ahora analisar mejor los datos, vamos ahora a aplicar un analisis con type, esto para saber mas exactamente que dato debemos tratar.

# %%
print(movies['genres'].head())
print(movies['genres'].apply(type).value_counts())
# Out:
# 0    [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1    [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2    [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3    [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                       [{'id': 35, 'name': 'Comedy'}]
# Name: genres, dtype: object
# genres
# <class 'list'>    45466
# Name: count, dtype: int64

# %% [markdown]
# Son `strings` asi que vamos a tratarlos como tal, con el metodo `json_normalize(dataframe['columnas])`

# %%
# Normaliza los diccionarios en la columna 'genres'
genres_df = pd.json_normalize(exploded_df['genres'])
genres_df
# Out:
#             id       name
# 0         16.0  Animation
# 1         35.0     Comedy
# 2      10751.0     Family
# 3         12.0  Adventure
# 4         14.0    Fantasy
# ...        ...        ...
# 93543     28.0     Action
# 93544     18.0      Drama
# 93545     53.0   Thriller
# 93546      NaN        NaN
# 93547      NaN        NaN
#
# [93548 rows x 2 columns]

# %% [markdown]
# Logramos hacer un dataframe con la columna generes desanidada, entonces vamos a hacer un joinc con el `dataframe` original

# %%
# Une los datos normalizados con el DataFrame original
final_df = exploded_df.drop(columns='genres').join(genres_df, lsuffix='_original', rsuffix='_genre')
final_df.head()
# Out:
#      budget id_original original_language  \
# 0  30000000         862                en
# 0  30000000         862                en
# 0  30000000         862                en
# 1  65000000        8844                en
# 1  65000000        8844                en
#
#                                             overview popularity  \
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 0  Led by Woody, Andy's toys live happily in his ...  21.946943
# 1  When siblings Judy and Peter discover an encha...  17.015539
# 1  When siblings Judy and Peter discover an encha...  17.015539
#
#                                 production_companies  \
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 0     [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1  [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# ...

# %%
# Normaliza los diccionarios en la columna 'production_companies'
print(movies['production_companies'].head())
print(movies['production_companies'].apply(type).value_counts())
movies['production_companies'] = movies['production_companies'].apply(ast.literal_eval)
exploded_df = movies.explode('production_companies')

production_companies_df = pd.json_normalize(movies['genproduction_companiesres'])
print(production_companies_df)
# Out:
# 0       [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1    [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2    [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3    [{'name': 'Twentieth Century Fox Film Corporat...
# 4    [{'name': 'Sandollar Productions', 'id': 5842}...
# Name: production_companies, dtype: object
# production_companies
# <class 'str'>      45463
# <class 'float'>        3
# Name: count, dtype: int64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 4
#       2 print(movies['production_companies'].head())
#       3 print(movies['production_companies'].apply(type).value_counts())
# ----> 4 movies['production_companies'] = movies['production_companies'].apply(ast.literal_eval)
#       5 exploded_df = movies.explode('production_companies')
#       7 production_companies_df = pd.json_normalize(movies['genproduction_companiesres'])
#
# ...
